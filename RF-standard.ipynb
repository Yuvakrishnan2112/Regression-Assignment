# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[["age","bmi","children","sex_male","smoker_yes"]]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)
X_train
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]],
#       shape=(936, 5))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {
    'criterion': ['squared_error', 'poisson', 'absolute_error', 'friedman_mse'],
    'n_estimators': [50, 100, 200],
    'max_features': [None, 'sqrt', 'log2']
}
grid = GridSearchCV(
    RandomForestRegressor(),
    param_grid,
    refit=True,
    verbose=3,
    n_jobs=-1
)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Anaconda\Lib\site-packages\sklearn\base.py:1365: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'poisson',
#                                        'absolute_error', 'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
re=grid.cv_results_
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.308201      0.030022         0.012926        0.002241
# 1        0.669192      0.072124         0.023339        0.004278
# 2        1.133623      0.064728         0.039838        0.002991
# 3        0.256978      0.021883         0.014369        0.003227
# 4        0.524301      0.039444         0.024083        0.004496
# 5        1.019572      0.080236         0.044231        0.005035
# 6        0.319390      0.056417         0.012207        0.001349
# 7        0.556820      0.042592         0.019975        0.001198
# 8        1.020567      0.087677         0.039367        0.008123
# 9        0.345981      0.035388         0.014782        0.003480
# 10       0.687958      0.032111         0.025101        0.005009
# 11       1.273108      0.049154         0.041211        0.004831
# 12       0.277298      0.022307         0.012856        0.001680
# 13       0.549843      0.036996         0.025046        0.006397
# 14       1.030388      0.041135         0.038470        0.007579
# 15       0.294946      0.041400         0.015381        0.004106
# 16       0.539718      0.053235         0.022913        0.005632
# 17       1.033849      0.060783         0.036385        0.005708
# 18       1.018758      0.081926         0.011475        0.001980
# 19       1.932853      0.133610         0.021440        0.003213
# 20       4.076386      0.313504         0.038116        0.006094
# 21       0.682129      0.048618         0.015379        0.003039
# 22       1.313332      0.134253         0.017621        0.000890
# 23       2.413817      0.116939         0.045687        0.013889
# 24       0.684893      0.037076         0.012192        0.002031
# 25       1.261238      0.154618         0.019794        0.004352
# 26       2.509502      0.139251         0.043560        0.006864
# 27       0.316307      0.031159         0.011630        0.000778
# 28       0.610849      0.025078         0.026879        0.003748
# 29       1.174822      0.090047         0.040850        0.005639
# 30       0.261957      0.025039         0.014441        0.001859
# 31       0.480800      0.049824         0.019633        0.001367
# 32       0.945766      0.033273         0.039888        0.002929
# 33       0.258411      0.036795         0.013289        0.004711
# 34       0.535664      0.036417         0.021346        0.001701
# 35       0.801506      0.082789         0.028127        0.001577
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  50
# 1    squared_error               None                 100
# 2    squared_error               None                 200
# 3    squared_error               sqrt                  50
# 4    squared_error               sqrt                 100
# 5    squared_error               sqrt                 200
# 6    squared_error               log2                  50
# 7    squared_error               log2                 100
# 8    squared_error               log2                 200
# 9          poisson               None                  50
# 10         poisson               None                 100
# 11         poisson               None                 200
# 12         poisson               sqrt                  50
# 13         poisson               sqrt                 100
# 14         poisson               sqrt                 200
# 15         poisson               log2                  50
# 16         poisson               log2                 100
# 17         poisson               log2                 200
# 18  absolute_error               None                  50
# 19  absolute_error               None                 100
# 20  absolute_error               None                 200
# 21  absolute_error               sqrt                  50
# 22  absolute_error               sqrt                 100
# 23  absolute_error               sqrt                 200
# 24  absolute_error               log2                  50
# 25  absolute_error               log2                 100
# 26  absolute_error               log2                 200
# 27    friedman_mse               None                  50
# 28    friedman_mse               None                 100
# 29    friedman_mse               None                 200
# 30    friedman_mse               sqrt                  50
# 31    friedman_mse               sqrt                 100
# 32    friedman_mse               sqrt                 200
# 33    friedman_mse               log2                  50
# 34    friedman_mse               log2                 100
# 35    friedman_mse               log2                 200
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.859570
# 1   {'criterion': 'squared_error', 'max_features':...           0.860216
# 2   {'criterion': 'squared_error', 'max_features':...           0.862263
# 3   {'criterion': 'squared_error', 'max_features':...           0.868317
# 4   {'criterion': 'squared_error', 'max_features':...           0.868294
# 5   {'criterion': 'squared_error', 'max_features':...           0.864125
# 6   {'criterion': 'squared_error', 'max_features':...           0.862799
# 7   {'criterion': 'squared_error', 'max_features':...           0.860821
# 8   {'criterion': 'squared_error', 'max_features':...           0.868746
# 9   {'criterion': 'poisson', 'max_features': None,...           0.862114
# 10  {'criterion': 'poisson', 'max_features': None,...           0.862377
# 11  {'criterion': 'poisson', 'max_features': None,...           0.864514
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.867036
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.864161
# 14  {'criterion': 'poisson', 'max_features': 'sqrt...           0.863995
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.860809
# 16  {'criterion': 'poisson', 'max_features': 'log2...           0.860721
# 17  {'criterion': 'poisson', 'max_features': 'log2...           0.860073
# 18  {'criterion': 'absolute_error', 'max_features'...           0.844231
# 19  {'criterion': 'absolute_error', 'max_features'...           0.850486
# 20  {'criterion': 'absolute_error', 'max_features'...           0.850951
# 21  {'criterion': 'absolute_error', 'max_features'...           0.854237
# 22  {'criterion': 'absolute_error', 'max_features'...           0.862876
# 23  {'criterion': 'absolute_error', 'max_features'...           0.859545
# 24  {'criterion': 'absolute_error', 'max_features'...           0.856071
# 25  {'criterion': 'absolute_error', 'max_features'...           0.863062
# 26  {'criterion': 'absolute_error', 'max_features'...           0.860419
# 27  {'criterion': 'friedman_mse', 'max_features': ...           0.863110
# 28  {'criterion': 'friedman_mse', 'max_features': ...           0.859860
# 29  {'criterion': 'friedman_mse', 'max_features': ...           0.863137
# 30  {'criterion': 'friedman_mse', 'max_features': ...           0.858737
# 31  {'criterion': 'friedman_mse', 'max_features': ...           0.862909
# 32  {'criterion': 'friedman_mse', 'max_features': ...           0.865557
# 33  {'criterion': 'friedman_mse', 'max_features': ...           0.861019
# 34  {'criterion': 'friedman_mse', 'max_features': ...           0.861996
# 35  {'criterion': 'friedman_mse', 'max_features': ...           0.866057
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0